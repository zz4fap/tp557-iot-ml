# %% [markdown]
# # Exercício sobre datasets e análise dos resultados de treinamento

# %% [markdown]
# **Observação**: Verifiquem se o uso de GPU está habilitado.

# %% [markdown]
# ## Importando as bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## Baixando o conjunto de dados MNIST
#
#
# O conjunto de dados MNIST de dígitos manuscritos, pode ser baixado com o [TF](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/mnist/load_data).
#
# O conjunto contém imagens 28x28 pixels em tons de cinza dos 10 dígitos (0-9).
# Ele possui um conjunto de treinamento com 60.000 imagens e um conjunto de teste com 10.000.

# %%
(ltrain_images, ltrain_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %% [markdown]
# ## Divindo em o conjunto inicial de treinamento em um conjunto de treinamento menor e um conjunto de validação

# %% [markdown]
# ### Separamos as primeiras 10.000 imagens para o conjunto de validação.

# %%
val_images = ltrain_images[:10000]
val_labels = ltrain_labels[:10000]

# %%
print(val_images.shape)
print(val_labels.shape)
# Out:
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# ### As 50.000 restantes vão para o novo conjunto de treinamento (menor)

# %%
train_images = ltrain_images[10000:]
train_labels = ltrain_labels[10000:]

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (50000, 28, 28)
# (50000,)

# %% [markdown]
# ## Pré-processamento dos dados
#
# Vamos aplicar normalização aos dados (i.e., atributos) dos três conjuntos.
#
# Como os valores dos pixels variam entre 0 e 255, basta dividí-los por 255.0 e o intervalo final ficará entre 0.0 e 1.0.

# %%
train_images  = train_images / 255.0
val_images = val_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# ## Execute a célula de código abaixo e analise as figuras geradas e os resultados de desempenho nos três conjuntos.

# %%
# Definindo o modelo.
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(20, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# Instanciando otimizador Adam.
opt = tf.keras.optimizers.Adam(learning_rate=0.1)

# Compilando a rede neural.
model.compile(
    optimizer=opt,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Treinando o modelo.
history = model.fit(
    train_images,
    train_labels,
    epochs=30,
    validation_data=(val_images, val_labels)
)

# Plotando os resultados de perda.
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Perda do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(loc='upper left')
plt.xticks(range(20))
plt.grid()
plt.show()

# Plotando os resultados de acurácia.
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Acurácia do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(loc='upper left')
plt.xticks(range(20))
plt.grid()
plt.show()

# Avaliando o desempenho no conjunto de treinamento.
print('Treinamento:', model.evaluate(train_images, train_labels))
# Avaliando o desempenho no conjunto de validação.
print('Validação:', model.evaluate(val_images, val_labels))
# Avaliando o desempenho no conjunto de teste.
print('Teste:', model.evaluate(test_images, test_labels))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4290 - accuracy: 0.5102 - val_loss: 1.4569 - val_accuracy: 0.4542
# Epoch 2/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5806 - accuracy: 0.4467 - val_loss: 1.6557 - val_accuracy: 0.3665
# Epoch 3/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6139 - accuracy: 0.4210 - val_loss: 1.6357 - val_accuracy: 0.4086
# Epoch 4/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6518 - accuracy: 0.4181 - val_loss: 1.7047 - val_accuracy: 0.4398
# Epoch 5/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6174 - accuracy: 0.4207 - val_loss: 1.6611 - val_accuracy: 0.4195
# Epoch 6/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5990 - accuracy: 0.4213 - val_loss: 1.6073 - val_accuracy: 0.4411
# Epoch 7/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6766 - accuracy: 0.3977 - val_loss: 1.7248 - val_accuracy: 0.4006
# Epoch 8/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6446 - accuracy: 0.4111 - val_loss: 1.7368 - val_accuracy: 0.4176
# Epoch 9/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5934 - accuracy: 0.4263 - val_loss: 1.8439 - val_accuracy: 0.4330
# Epoch 10/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.6268 - accuracy: 0.4196 - val_loss: 1.8910 - val_accuracy: 0.4596
# Epoch 11/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.6148 - accuracy: 0.4211 - val_loss: 1.7543 - val_accuracy: 0.4283
# Epoch 12/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6141 - accuracy: 0.4233 - val_loss: 1.7508 - val_accuracy: 0.4157
# Epoch 13/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5452 - accuracy: 0.4307 - val_loss: 2.0237 - val_accuracy: 0.4524
# Epoch 14/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5848 - accuracy: 0.4205 - val_loss: 1.8647 - val_accuracy: 0.4426
# Epoch 15/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6103 - accuracy: 0.4138 - val_loss: 1.8507 - val_accuracy: 0.4247
# Epoch 16/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6160 - accuracy: 0.4185 - val_loss: 2.6443 - val_accuracy: 0.4604
# Epoch 17/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6002 - accuracy: 0.4211 - val_loss: 2.6014 - val_accuracy: 0.4639
# Epoch 18/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5672 - accuracy: 0.4373 - val_loss: 2.0221 - val_accuracy: 0.4223
# Epoch 19/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5472 - accuracy: 0.4284 - val_loss: 2.1142 - val_accuracy: 0.4343
# Epoch 20/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5542 - accuracy: 0.4323 - val_loss: 2.0817 - val_accuracy: 0.4352
# Epoch 21/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5776 - accuracy: 0.4333 - val_loss: 2.6350 - val_accuracy: 0.4363
# Epoch 22/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5910 - accuracy: 0.4122 - val_loss: 2.3169 - val_accuracy: 0.4349
# Epoch 23/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5270 - accuracy: 0.4353 - val_loss: 2.2645 - val_accuracy: 0.4673
# Epoch 24/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5501 - accuracy: 0.4386 - val_loss: 1.9627 - val_accuracy: 0.4509
# Epoch 25/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5361 - accuracy: 0.4300 - val_loss: 2.0182 - val_accuracy: 0.4396
# Epoch 26/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5429 - accuracy: 0.4253 - val_loss: 2.4760 - val_accuracy: 0.4185
# Epoch 27/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5614 - accuracy: 0.4262 - val_loss: 2.4645 - val_accuracy: 0.4066
# Epoch 28/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6551 - accuracy: 0.4214 - val_loss: 2.9478 - val_accuracy: 0.4619
# Epoch 29/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5645 - accuracy: 0.4232 - val_loss: 2.3077 - val_accuracy: 0.4209
# Epoch 30/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5225 - accuracy: 0.4400 - val_loss: 2.0200 - val_accuracy: 0.4403
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4952 - accuracy: 0.4332
# Treinamento: [1.4951776266098022, 0.4332199990749359]
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0200 - accuracy: 0.4403
# Validação; [2.019975185394287, 0.44029998779296875]
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0296 - accuracy: 0.4317
# Teste: [2.0296247005462646, 0.4316999912261963]

# %% [markdown]
# ### O que você conclui sobre o treinamento deste modelo? Podemos dizer que o modelo treinado tem um bom desempenho? Caso não, o que pode ser feito para melhorar este desempenho? *Justifique suas respostas*
#
# **Reposta**
#
# Escreva sua resposta aqui.

# %% [markdown]
# ## Execute a célula de código abaixo e analise as figuras geradas e os resultados de desempenho nos três conjuntos.

# %%
# Definindo o modelo.
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(20, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# Instanciando otimizador Adam.
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

# Compilando a rede neural.
model.compile(
    optimizer=opt,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Treinando o modelo.
epochs = 40
history = model.fit(
    train_images,
    train_labels,
    epochs=epochs,
    validation_data=(val_images, val_labels)
)

# Plotando os resultados de perda.
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Perda do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# Plotando os resultados de acurácia.
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Acurácia do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# Avaliando o desempenho no conjunto de treinamento.
print('Treinamento:', model.evaluate(train_images, train_labels))
# Avaliando o desempenho no conjunto de validação.
print('Validação:', model.evaluate(val_images, val_labels))
# Avaliando o desempenho no conjunto de teste.
print('Teste:', model.evaluate(test_images, test_labels))
# Out:
# Epoch 1/40
# 1563/1563 [==============================] - 6s 3ms/step - loss: 1.1371 - accuracy: 0.7174 - val_loss: 0.5899 - val_accuracy: 0.8639
# Epoch 2/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4869 - accuracy: 0.8776 - val_loss: 0.3998 - val_accuracy: 0.8957
# Epoch 3/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.3755 - accuracy: 0.8983 - val_loss: 0.3377 - val_accuracy: 0.9099
# Epoch 4/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.3291 - accuracy: 0.9091 - val_loss: 0.3066 - val_accuracy: 0.9145
# Epoch 5/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.3019 - accuracy: 0.9157 - val_loss: 0.2860 - val_accuracy: 0.9214
# Epoch 6/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2830 - accuracy: 0.9197 - val_loss: 0.2718 - val_accuracy: 0.9245
# Epoch 7/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2685 - accuracy: 0.9241 - val_loss: 0.2608 - val_accuracy: 0.9269
# Epoch 8/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2567 - accuracy: 0.9271 - val_loss: 0.2513 - val_accuracy: 0.9311
# Epoch 9/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2467 - accuracy: 0.9308 - val_loss: 0.2432 - val_accuracy: 0.9318
# Epoch 10/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2382 - accuracy: 0.9327 - val_loss: 0.2360 - val_accuracy: 0.9341
# Epoch 11/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2306 - accuracy: 0.9346 - val_loss: 0.2306 - val_accuracy: 0.9349
# Epoch 12/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2239 - accuracy: 0.9367 - val_loss: 0.2244 - val_accuracy: 0.9376
# Epoch 13/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2180 - accuracy: 0.9383 - val_loss: 0.2203 - val_accuracy: 0.9375
# Epoch 14/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2127 - accuracy: 0.9397 - val_loss: 0.2160 - val_accuracy: 0.9392
# Epoch 15/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.2078 - accuracy: 0.9406 - val_loss: 0.2134 - val_accuracy: 0.9390
# Epoch 16/40
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2033 - accuracy: 0.9420 - val_loss: 0.2093 - val_accuracy: 0.9407
# Epoch 17/40
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1993 - accuracy: 0.9437 - val_loss: 0.2060 - val_accuracy: 0.9412
# Epoch 18/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1954 - accuracy: 0.9449 - val_loss: 0.2029 - val_accuracy: 0.9424
# Epoch 19/40
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1918 - accuracy: 0.9454 - val_loss: 0.2009 - val_accuracy: 0.9439
# Epoch 20/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1883 - accuracy: 0.9463 - val_loss: 0.1981 - val_accuracy: 0.9446
# Epoch 21/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1850 - accuracy: 0.9472 - val_loss: 0.1955 - val_accuracy: 0.9453
# Epoch 22/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1819 - accuracy: 0.9483 - val_loss: 0.1933 - val_accuracy: 0.9465
# Epoch 23/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1789 - accuracy: 0.9490 - val_loss: 0.1910 - val_accuracy: 0.9457
# Epoch 24/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1761 - accuracy: 0.9501 - val_loss: 0.1897 - val_accuracy: 0.9463
# Epoch 25/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1733 - accuracy: 0.9508 - val_loss: 0.1866 - val_accuracy: 0.9457
# Epoch 26/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1709 - accuracy: 0.9514 - val_loss: 0.1851 - val_accuracy: 0.9470
# Epoch 27/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1685 - accuracy: 0.9522 - val_loss: 0.1835 - val_accuracy: 0.9461
# Epoch 28/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1662 - accuracy: 0.9528 - val_loss: 0.1820 - val_accuracy: 0.9468
# Epoch 29/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1640 - accuracy: 0.9532 - val_loss: 0.1810 - val_accuracy: 0.9474
# Epoch 30/40
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1619 - accuracy: 0.9536 - val_loss: 0.1795 - val_accuracy: 0.9477
# Epoch 31/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.1598 - accuracy: 0.9550 - val_loss: 0.1783 - val_accuracy: 0.9482
# Epoch 32/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1577 - accuracy: 0.9556 - val_loss: 0.1761 - val_accuracy: 0.9489
# Epoch 33/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1560 - accuracy: 0.9556 - val_loss: 0.1756 - val_accuracy: 0.9492
# Epoch 34/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.1541 - accuracy: 0.9563 - val_loss: 0.1754 - val_accuracy: 0.9501
# Epoch 35/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1523 - accuracy: 0.9570 - val_loss: 0.1729 - val_accuracy: 0.9507
# Epoch 36/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.1506 - accuracy: 0.9573 - val_loss: 0.1719 - val_accuracy: 0.9506
# Epoch 37/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1487 - accuracy: 0.9578 - val_loss: 0.1717 - val_accuracy: 0.9506
# Epoch 38/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1474 - accuracy: 0.9579 - val_loss: 0.1698 - val_accuracy: 0.9516
# Epoch 39/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1455 - accuracy: 0.9589 - val_loss: 0.1686 - val_accuracy: 0.9523
# Epoch 40/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1439 - accuracy: 0.9589 - val_loss: 0.1682 - val_accuracy: 0.9523
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.1410 - accuracy: 0.9601
# [0.1409996747970581, 0.960099995136261]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1682 - accuracy: 0.9523
# [0.1681724488735199, 0.9523000121116638]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1644 - accuracy: 0.9508
# [0.16443610191345215, 0.9508000016212463]

# %% [markdown]
# ### O que você conclui sobre o treinamento deste outro modelo? Podemos dizer que o modelo treinado tem um bom desempenho? Caso não, o que pode ser feito para melhorar este desempenho? *Justifique suas respostas*
#
# **Reposta**
#
# Escreva sua resposta aqui.

# %% [markdown]
# ## Execute a célula de código abaixo e analise o código (mais especificamente a arquitetura da rede neural), as figuras geradas e os resultados de desempenho nos três conjuntos.

# %%
# Definindo o modelo.
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# Instanciando otimizador Adam.
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

# Compilando a rede neural.
model.compile(
    optimizer=opt,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Treinando o modelo.
epochs = 100
history = model.fit(
    train_images,
    train_labels,
    epochs=epochs,
    validation_data=(val_images, val_labels)
)

# Plotando os resultados de perda.
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Perda do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# Plotando os resultados de acurácia.
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Acurácia do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# Avaliando o desempenho no conjunto de treinamento.
print('Treinamento:', model.evaluate(train_images, train_labels))
# Avaliando o desempenho no conjunto de validação.
print('Validação:', model.evaluate(val_images, val_labels))
# Avaliando o desempenho no conjunto de teste.
print('Teste:', model.evaluate(test_images, test_labels))
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6461 - accuracy: 0.8241 - val_loss: 0.2902 - val_accuracy: 0.9189
# Epoch 2/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2548 - accuracy: 0.9281 - val_loss: 0.2270 - val_accuracy: 0.9354
# Epoch 3/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2014 - accuracy: 0.9427 - val_loss: 0.1917 - val_accuracy: 0.9459
# Epoch 4/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.1698 - accuracy: 0.9521 - val_loss: 0.1682 - val_accuracy: 0.9519
# Epoch 5/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.1470 - accuracy: 0.9575 - val_loss: 0.1513 - val_accuracy: 0.9571
# Epoch 6/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.1285 - accuracy: 0.9638 - val_loss: 0.1385 - val_accuracy: 0.9611
# Epoch 7/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1140 - accuracy: 0.9668 - val_loss: 0.1336 - val_accuracy: 0.9625
# Epoch 8/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1017 - accuracy: 0.9706 - val_loss: 0.1260 - val_accuracy: 0.9649
# Epoch 9/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.0917 - accuracy: 0.9737 - val_loss: 0.1191 - val_accuracy: 0.9651
# Epoch 10/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0828 - accuracy: 0.9759 - val_loss: 0.1100 - val_accuracy: 0.9686
# Epoch 11/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0741 - accuracy: 0.9788 - val_loss: 0.1105 - val_accuracy: 0.9683
# Epoch 12/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0676 - accuracy: 0.9803 - val_loss: 0.1059 - val_accuracy: 0.9689
# Epoch 13/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.0617 - accuracy: 0.9823 - val_loss: 0.1033 - val_accuracy: 0.9691
# Epoch 14/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0554 - accuracy: 0.9842 - val_loss: 0.1027 - val_accuracy: 0.9695
# Epoch 15/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0505 - accuracy: 0.9857 - val_loss: 0.1000 - val_accuracy: 0.9712
# Epoch 16/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0461 - accuracy: 0.9869 - val_loss: 0.0953 - val_accuracy: 0.9720
# Epoch 17/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0414 - accuracy: 0.9882 - val_loss: 0.0939 - val_accuracy: 0.9729
# Epoch 18/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0378 - accuracy: 0.9896 - val_loss: 0.0930 - val_accuracy: 0.9725
# Epoch 19/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.0345 - accuracy: 0.9907 - val_loss: 0.0955 - val_accuracy: 0.9713
# Epoch 20/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0313 - accuracy: 0.9916 - val_loss: 0.0955 - val_accuracy: 0.9719
# Epoch 21/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0281 - accuracy: 0.9928 - val_loss: 0.0929 - val_accuracy: 0.9731
# Epoch 22/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0256 - accuracy: 0.9932 - val_loss: 0.0960 - val_accuracy: 0.9731
# Epoch 23/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0235 - accuracy: 0.9936 - val_loss: 0.0936 - val_accuracy: 0.9749
# Epoch 24/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0208 - accuracy: 0.9953 - val_loss: 0.0910 - val_accuracy: 0.9746
# Epoch 25/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0186 - accuracy: 0.9958 - val_loss: 0.0960 - val_accuracy: 0.9737
# Epoch 26/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0169 - accuracy: 0.9963 - val_loss: 0.0985 - val_accuracy: 0.9749
# Epoch 27/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0155 - accuracy: 0.9965 - val_loss: 0.0910 - val_accuracy: 0.9769
# Epoch 28/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0136 - accuracy: 0.9971 - val_loss: 0.0964 - val_accuracy: 0.9740
# Epoch 29/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0119 - accuracy: 0.9976 - val_loss: 0.0992 - val_accuracy: 0.9748
# Epoch 30/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0112 - accuracy: 0.9977 - val_loss: 0.1045 - val_accuracy: 0.9751
# Epoch 31/100
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.0097 - accuracy: 0.9983 - val_loss: 0.1010 - val_accuracy: 0.9747
# Epoch 32/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0084 - accuracy: 0.9986 - val_loss: 0.1050 - val_accuracy: 0.9740
# Epoch 33/100
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.0080 - accuracy: 0.9988 - val_loss: 0.1039 - val_accuracy: 0.9752
# Epoch 34/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0067 - accuracy: 0.9991 - val_loss: 0.1105 - val_accuracy: 0.9732
# Epoch 35/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0059 - accuracy: 0.9991 - val_loss: 0.1100 - val_accuracy: 0.9737
# Epoch 36/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0055 - accuracy: 0.9992 - val_loss: 0.1038 - val_accuracy: 0.9756
# Epoch 37/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.1086 - val_accuracy: 0.9754
# Epoch 38/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.1227 - val_accuracy: 0.9712
# Epoch 39/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.1199 - val_accuracy: 0.9739
# Epoch 40/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.1088 - val_accuracy: 0.9763
# Epoch 41/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.1180 - val_accuracy: 0.9730
# Epoch 42/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.1141 - val_accuracy: 0.9760
# Epoch 43/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.1151 - val_accuracy: 0.9751
# Epoch 44/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.1223 - val_accuracy: 0.9759
# Epoch 45/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.1155 - val_accuracy: 0.9769
# Epoch 46/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9759
# Epoch 47/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.1306 - val_accuracy: 0.9735
# Epoch 48/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.1220 - val_accuracy: 0.9754
# Epoch 49/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.1243 - val_accuracy: 0.9765
# Epoch 50/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.1231 - val_accuracy: 0.9757
# Epoch 51/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 9.2616e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9759
# Epoch 52/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1471 - val_accuracy: 0.9734
# Epoch 53/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.1295 - val_accuracy: 0.9746
# Epoch 54/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 5.1574e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9761
# Epoch 55/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1573 - val_accuracy: 0.9712
# Epoch 56/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1312 - val_accuracy: 0.9768
# Epoch 57/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 3.9275e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9770
# Epoch 58/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.1428 - val_accuracy: 0.9747
# Epoch 59/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 4.6994e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9752
# Epoch 60/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 3.0771e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9762
# Epoch 61/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1451 - val_accuracy: 0.9751
# Epoch 62/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 3.9720e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9767
# Epoch 63/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1770 - val_accuracy: 0.9721
# Epoch 64/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 7.7993e-04 - accuracy: 0.9999 - val_loss: 0.1491 - val_accuracy: 0.9757
# Epoch 65/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.4754e-04 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9762
# Epoch 66/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0467e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9764
# Epoch 67/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.1549 - val_accuracy: 0.9750
# Epoch 68/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 4.2025e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9768
# Epoch 69/100
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.7457e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9766
# Epoch 70/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4485e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9769
# Epoch 71/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1558 - val_accuracy: 0.9755
# Epoch 72/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 3.2469e-04 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9755
# Epoch 73/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4391e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9760
# Epoch 74/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2127e-04 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9761
# Epoch 75/100
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1581 - val_accuracy: 0.9747
# Epoch 76/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 3.9036e-04 - accuracy: 0.9999 - val_loss: 0.1553 - val_accuracy: 0.9761
# Epoch 77/100
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.1818e-04 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9754
# Epoch 78/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0385e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9757
# Epoch 79/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.1588 - val_accuracy: 0.9757
# Epoch 80/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 3.5545e-04 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 0.9755
# Epoch 81/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3081e-04 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9762
# Epoch 82/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 8.2923e-05 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9765
# Epoch 83/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.1577 - val_accuracy: 0.9762
# Epoch 84/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.8638e-04 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.9768
# Epoch 85/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 9.6521e-05 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9769
# Epoch 86/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 7.5303e-05 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9777
# Epoch 87/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 3.1970e-04 - accuracy: 1.0000 - val_loss: 0.1808 - val_accuracy: 0.9723
# Epoch 88/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1531 - val_accuracy: 0.9765
# Epoch 89/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0235e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9773
# Epoch 90/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 6.8109e-05 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9766
# Epoch 91/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 5.6573e-05 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9775
# Epoch 92/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.1615 - val_accuracy: 0.9764
# Epoch 93/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 3.2729e-04 - accuracy: 0.9999 - val_loss: 0.1583 - val_accuracy: 0.9768
# Epoch 94/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 8.0951e-05 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9776
# Epoch 95/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 5.7531e-05 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9773
# Epoch 96/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 4.8683e-05 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9780
# Epoch 97/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1654 - val_accuracy: 0.9766
# Epoch 98/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3176e-04 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.9773
# Epoch 99/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 5.4425e-05 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9773
# Epoch 100/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 4.0908e-05 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9766

# %% [markdown]
# ### O que você conclui sobre o treinamento deste outro modelo? Podemos dizer que o modelo treinado tem um bom desempenho? Caso não, o que pode ser feito para melhorar este desempenho? *Justifique suas respostas*
#
# **Reposta**
#
# Escreva sua resposta aqui.

# %% [markdown]
# ## Execute a célula de código abaixo e analise as figuras geradas e os resultados de desempenho nos três conjuntos.

# %%
# Definindo o modelo.
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(20, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# Instanciando otimizador Adam.
opt = tf.keras.optimizers.Adam(learning_rate=0.0000001)

# Compilando a rede neural.
model.compile(
    optimizer=opt,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Treinando o modelo.
epochs = 40
history = model.fit(
    train_images,
    train_labels,
    epochs=epochs,
    validation_data=(val_images, val_labels)
)

# Plotando os resultados de perda.
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Perda do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# Plotando os resultados de acurácia.
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Acurácia do modelo')
plt.ylabel('Acurácia')
plt.xlabel('Época')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# Avaliando o desempenho no conjunto de treinamento.
print('Treinamento:', model.evaluate(train_images, train_labels))
# Avaliando o desempenho no conjunto de validação.
print('Validação:', model.evaluate(val_images, val_labels))
# Avaliando o desempenho no conjunto de teste.
print('Teste:', model.evaluate(test_images, test_labels))
# Out:
# Epoch 1/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.3488 - accuracy: 0.1457 - val_loss: 2.3174 - val_accuracy: 0.1626
# Epoch 2/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3037 - accuracy: 0.1774 - val_loss: 2.2741 - val_accuracy: 0.1955
# Epoch 3/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.2612 - accuracy: 0.2111 - val_loss: 2.2326 - val_accuracy: 0.2315
# Epoch 4/40
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.2204 - accuracy: 0.2451 - val_loss: 2.1921 - val_accuracy: 0.2672
# Epoch 5/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.1805 - accuracy: 0.2790 - val_loss: 2.1524 - val_accuracy: 0.2997
# Epoch 6/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.1413 - accuracy: 0.3116 - val_loss: 2.1132 - val_accuracy: 0.3299
# Epoch 7/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.1023 - accuracy: 0.3420 - val_loss: 2.0742 - val_accuracy: 0.3628
# Epoch 8/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0634 - accuracy: 0.3715 - val_loss: 2.0351 - val_accuracy: 0.3961
# Epoch 9/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.0246 - accuracy: 0.4018 - val_loss: 1.9960 - val_accuracy: 0.4266
# Epoch 10/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9859 - accuracy: 0.4301 - val_loss: 1.9572 - val_accuracy: 0.4543
# Epoch 11/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9475 - accuracy: 0.4585 - val_loss: 1.9188 - val_accuracy: 0.4828
# Epoch 12/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9099 - accuracy: 0.4832 - val_loss: 1.8812 - val_accuracy: 0.5063
# Epoch 13/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8730 - accuracy: 0.5048 - val_loss: 1.8444 - val_accuracy: 0.5247
# Epoch 14/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8370 - accuracy: 0.5235 - val_loss: 1.8086 - val_accuracy: 0.5426
# Epoch 15/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8021 - accuracy: 0.5408 - val_loss: 1.7738 - val_accuracy: 0.5600
# Epoch 16/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.7682 - accuracy: 0.5557 - val_loss: 1.7400 - val_accuracy: 0.5726
# Epoch 17/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7353 - accuracy: 0.5690 - val_loss: 1.7071 - val_accuracy: 0.5864
# Epoch 18/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7033 - accuracy: 0.5801 - val_loss: 1.6752 - val_accuracy: 0.6001
# Epoch 19/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6723 - accuracy: 0.5902 - val_loss: 1.6444 - val_accuracy: 0.6113
# Epoch 20/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6423 - accuracy: 0.6008 - val_loss: 1.6144 - val_accuracy: 0.6233
# Epoch 21/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6131 - accuracy: 0.6108 - val_loss: 1.5853 - val_accuracy: 0.6326
# Epoch 22/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5847 - accuracy: 0.6202 - val_loss: 1.5570 - val_accuracy: 0.6414
# Epoch 23/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5571 - accuracy: 0.6284 - val_loss: 1.5294 - val_accuracy: 0.6503
# Epoch 24/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5303 - accuracy: 0.6373 - val_loss: 1.5027 - val_accuracy: 0.6587
# Epoch 25/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5042 - accuracy: 0.6457 - val_loss: 1.4767 - val_accuracy: 0.6669
# Epoch 26/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4788 - accuracy: 0.6544 - val_loss: 1.4514 - val_accuracy: 0.6759
# Epoch 27/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4541 - accuracy: 0.6615 - val_loss: 1.4268 - val_accuracy: 0.6835
# Epoch 28/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4300 - accuracy: 0.6690 - val_loss: 1.4028 - val_accuracy: 0.6908
# Epoch 29/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4066 - accuracy: 0.6770 - val_loss: 1.3795 - val_accuracy: 0.6985
# Epoch 30/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3838 - accuracy: 0.6833 - val_loss: 1.3567 - val_accuracy: 0.7042
# Epoch 31/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3616 - accuracy: 0.6896 - val_loss: 1.3346 - val_accuracy: 0.7102
# Epoch 32/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3400 - accuracy: 0.6951 - val_loss: 1.3131 - val_accuracy: 0.7167
# Epoch 33/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3190 - accuracy: 0.7002 - val_loss: 1.2921 - val_accuracy: 0.7225
# Epoch 34/40
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.2985 - accuracy: 0.7061 - val_loss: 1.2716 - val_accuracy: 0.7277
# Epoch 35/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2784 - accuracy: 0.7124 - val_loss: 1.2517 - val_accuracy: 0.7321
# Epoch 36/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2589 - accuracy: 0.7169 - val_loss: 1.2322 - val_accuracy: 0.7369
# Epoch 37/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2398 - accuracy: 0.7224 - val_loss: 1.2132 - val_accuracy: 0.7410
# Epoch 38/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2213 - accuracy: 0.7270 - val_loss: 1.1948 - val_accuracy: 0.7467
# Epoch 39/40
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2032 - accuracy: 0.7312 - val_loss: 1.1767 - val_accuracy: 0.7507
# Epoch 40/40
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1856 - accuracy: 0.7355 - val_loss: 1.1592 - val_accuracy: 0.7539
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.1769 - accuracy: 0.7371
# Treinamento: [1.1769189834594727, 0.7371000051498413]
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1592 - accuracy: 0.7539
# Validação; [1.1591511964797974, 0.7538999915122986]
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1563 - accuracy: 0.7483
# Teste: [1.1562681198120117, 0.7483000159263611]

# %% [markdown]
# ### O que você conclui sobre o treinamento deste outro modelo? Podemos dizer que o modelo treinado tem um bom desempenho? Caso não, o que pode ser feito para melhorar este desempenho? Compare os resultados das figuras acima com os resultados obtidos com o treinamento do segundo modelo. *Justifique suas respostas*
#
# **Reposta**
#
# Escreva sua resposta aqui.
