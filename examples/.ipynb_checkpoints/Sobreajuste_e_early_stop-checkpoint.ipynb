# %% [markdown]
# # Sobreajuste e early stopping
#
# O "early stopping" (ou parada antecipada) é uma técnica de regularização utilizada em treinamento de redes neurais para evitar o sobreajuste e encontrar um ponto ótimo de convergência durante o treinamento. A ideia fundamental por trás do early stopping é interromper o treinamento do modelo assim que o desempenho em um conjunto de validação começa a piorar, em vez de continuar até que o modelo se ajuste demais aos dados de treinamento. O early stopping funciona da seguinte forma:
#
# 1. **Conjunto de Treinamento e Conjunto de Validação**: Durante o treinamento de uma rede neural, geralmente divide-se o conjunto de dados em dois subconjuntos: um conjunto de treinamento usado para atualizar os pesos do modelo e um conjunto de validação usado para avaliar o desempenho do modelo em dados não vistos durante o treinamento.
#
# 2. **Monitoramento de Métricas**: À medida que o treinamento progride, as métricas de desempenho, como erro ou precisão, são calculadas regularmente no conjunto de validação. Essas métricas fornecem uma indicação de quão bem o modelo está generalizando para novos dados.
#
# 3. **Critério de Parada**: O critério de parada é uma métrica escolhida com base no problema e nas metas do treinamento. Pode ser o erro de validação, a precisão ou qualquer outra métrica relevante. O treinamento é interrompido quando a métrica de validação não melhora mais ou começa a piorar.
#
# 4. **Recuperação do Melhor Modelo**: Ao interromper o treinamento, o modelo é revertido para o ponto em que obteve o melhor desempenho no conjunto de validação. Esse modelo é então usado para inferência e avaliação em novos dados.
#
# Os benefícios do early stopping incluem:
#
# - Evita o sobreajuste: Ao interromper o treinamento antes que o modelo se ajuste demais aos dados de treinamento, o early stopping ajuda a obter modelos mais generalizados e melhores em dados de teste não vistos.
#
# - Economiza tempo e recursos computacionais: O treinamento de redes neurais pode ser computacionalmente intensivo, e o early stopping pode ajudar a economizar tempo e recursos interrompendo o treinamento assim que não houver mais ganho significativo no desempenho.
#
# - Melhora a robustez: Modelos treinados com early stopping tendem a ser mais robustos e menos sensíveis a variações nos dados de treinamento.

# %% [markdown]
# ## Baixando e normalizando os dados.
#
# Utilizaremos a base de dados conhecida como CIFAR10. Ela possui 60.000 imagens **coloridas** com dimensão $32 \times 32 \times 3$, ou seja, elas têm 3 dimensões (ou canais), uma para cada uma das três cores, RGB (vermelho, verde e azul).
#
# Usaremos 50.000 imagens para treinamento e 10.000 imagens para validação. As imagens pertencem a 10 classes, as quais são listadas abaixo.
#
# | Rótulo |  Descrição |
# |:------:|:----------:|
# |    0   |  airplane  |
# |    1   | automobile |
# |    2   |    bird    |
# |    3   |     cat    |
# |    4   |    deer    |
# |    5   |     dog    |
# |    6   |    frog    |
# |    7   |    horse   |
# |    8   |    ship    |
# |    9   |    truck   |

# %%
# TensorFlow
import tensorflow as tf

# Bibliotecas Auxiliares
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Download the dataset.
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

# Reshaping the label arrays.
train_labels = train_labels.reshape(-1,)
test_labels = test_labels.reshape(-1,)

# Defining the class names.
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Scaling.
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# ## Criando, configurando e treinando uma rede neural convolucional

# %%
# Define VGG model.
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(filters=128,kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=1024, activation='relu', kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(units=512, activation='relu', kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

# Compile the defined model.
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the VGG model.
history = model.fit(train_images, train_labels, batch_size=64, validation_data=(test_images, test_labels), epochs=100)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 11s 10ms/step - loss: 1.4987 - accuracy: 0.4475 - val_loss: 1.1517 - val_accuracy: 0.5898
# Epoch 2/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.9727 - accuracy: 0.6555 - val_loss: 0.9845 - val_accuracy: 0.6642
# Epoch 3/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.7526 - accuracy: 0.7346 - val_loss: 0.7916 - val_accuracy: 0.7284
# Epoch 4/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.6087 - accuracy: 0.7855 - val_loss: 0.7718 - val_accuracy: 0.7492
# Epoch 5/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.4915 - accuracy: 0.8290 - val_loss: 0.8598 - val_accuracy: 0.7213
# Epoch 6/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.3870 - accuracy: 0.8629 - val_loss: 0.8242 - val_accuracy: 0.7448
# Epoch 7/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.3039 - accuracy: 0.8917 - val_loss: 0.7970 - val_accuracy: 0.7641
# Epoch 8/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.2342 - accuracy: 0.9184 - val_loss: 0.9308 - val_accuracy: 0.7650
# Epoch 9/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1866 - accuracy: 0.9345 - val_loss: 0.9973 - val_accuracy: 0.7594
# Epoch 10/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1609 - accuracy: 0.9443 - val_loss: 1.0820 - val_accuracy: 0.7614
# Epoch 11/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1389 - accuracy: 0.9525 - val_loss: 1.0915 - val_accuracy: 0.7543
# Epoch 12/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1295 - accuracy: 0.9554 - val_loss: 1.2936 - val_accuracy: 0.7664
# Epoch 13/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1137 - accuracy: 0.9610 - val_loss: 1.1986 - val_accuracy: 0.7539
# Epoch 14/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1086 - accuracy: 0.9638 - val_loss: 1.2880 - val_accuracy: 0.7596
# Epoch 15/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0983 - accuracy: 0.9668 - val_loss: 1.4245 - val_accuracy: 0.7471
# Epoch 16/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0943 - accuracy: 0.9685 - val_loss: 1.4201 - val_accuracy: 0.7549
# Epoch 17/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0984 - accuracy: 0.9686 - val_loss: 1.4096 - val_accuracy: 0.7497
# Epoch 18/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0898 - accuracy: 0.9712 - val_loss: 1.4226 - val_accuracy: 0.7582
# Epoch 19/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0856 - accuracy: 0.9723 - val_loss: 1.3903 - val_accuracy: 0.7603
# Epoch 20/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0904 - accuracy: 0.9715 - val_loss: 1.4775 - val_accuracy: 0.7512
# Epoch 21/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0788 - accuracy: 0.9749 - val_loss: 1.7272 - val_accuracy: 0.7452
# Epoch 22/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0887 - accuracy: 0.9718 - val_loss: 1.4764 - val_accuracy: 0.7569
# Epoch 23/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0884 - accuracy: 0.9721 - val_loss: 1.5567 - val_accuracy: 0.7555
# Epoch 24/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0697 - accuracy: 0.9777 - val_loss: 1.6544 - val_accuracy: 0.7515
# Epoch 25/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0882 - accuracy: 0.9726 - val_loss: 1.5784 - val_accuracy: 0.7582
# Epoch 26/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0681 - accuracy: 0.9787 - val_loss: 1.6406 - val_accuracy: 0.7572
# Epoch 27/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0773 - accuracy: 0.9762 - val_loss: 1.5674 - val_accuracy: 0.7615
# Epoch 28/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0722 - accuracy: 0.9779 - val_loss: 1.8242 - val_accuracy: 0.7450
# Epoch 29/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0718 - accuracy: 0.9776 - val_loss: 1.6983 - val_accuracy: 0.7582
# Epoch 30/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0723 - accuracy: 0.9777 - val_loss: 1.9420 - val_accuracy: 0.7463
# Epoch 31/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0782 - accuracy: 0.9759 - val_loss: 1.7182 - val_accuracy: 0.7478
# Epoch 32/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0688 - accuracy: 0.9784 - val_loss: 1.7100 - val_accuracy: 0.7597
# Epoch 33/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0707 - accuracy: 0.9790 - val_loss: 1.6798 - val_accuracy: 0.7451
# Epoch 34/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0677 - accuracy: 0.9798 - val_loss: 1.9850 - val_accuracy: 0.7410
# Epoch 35/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0682 - accuracy: 0.9800 - val_loss: 1.9530 - val_accuracy: 0.7480
# Epoch 36/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0709 - accuracy: 0.9783 - val_loss: 2.0140 - val_accuracy: 0.7367
# Epoch 37/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0761 - accuracy: 0.9771 - val_loss: 1.7794 - val_accuracy: 0.7573
# Epoch 38/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0671 - accuracy: 0.9805 - val_loss: 1.9215 - val_accuracy: 0.7426
# Epoch 39/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0708 - accuracy: 0.9790 - val_loss: 1.8089 - val_accuracy: 0.7474
# Epoch 40/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0606 - accuracy: 0.9814 - val_loss: 1.9425 - val_accuracy: 0.7479
# Epoch 41/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0632 - accuracy: 0.9821 - val_loss: 1.9332 - val_accuracy: 0.7576
# Epoch 42/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0687 - accuracy: 0.9804 - val_loss: 1.8561 - val_accuracy: 0.7495
# Epoch 43/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0644 - accuracy: 0.9815 - val_loss: 2.1443 - val_accuracy: 0.7454
# Epoch 44/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0736 - accuracy: 0.9789 - val_loss: 2.0595 - val_accuracy: 0.7425
# Epoch 45/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0698 - accuracy: 0.9803 - val_loss: 1.9181 - val_accuracy: 0.7577
# Epoch 46/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0571 - accuracy: 0.9838 - val_loss: 1.9677 - val_accuracy: 0.7583
# Epoch 47/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0680 - accuracy: 0.9808 - val_loss: 2.1192 - val_accuracy: 0.7518
# Epoch 48/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0652 - accuracy: 0.9818 - val_loss: 2.1698 - val_accuracy: 0.7503
# Epoch 49/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0658 - accuracy: 0.9820 - val_loss: 2.1323 - val_accuracy: 0.7497
# Epoch 50/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0656 - accuracy: 0.9816 - val_loss: 2.1260 - val_accuracy: 0.7607
# Epoch 51/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0565 - accuracy: 0.9844 - val_loss: 2.1510 - val_accuracy: 0.7503
# Epoch 52/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0710 - accuracy: 0.9799 - val_loss: 1.9292 - val_accuracy: 0.7570
# Epoch 53/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0648 - accuracy: 0.9823 - val_loss: 2.1264 - val_accuracy: 0.7533
# Epoch 54/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0613 - accuracy: 0.9831 - val_loss: 2.0819 - val_accuracy: 0.7465
# Epoch 55/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0602 - accuracy: 0.9842 - val_loss: 1.8760 - val_accuracy: 0.7551
# Epoch 56/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0641 - accuracy: 0.9830 - val_loss: 1.8935 - val_accuracy: 0.7471
# Epoch 57/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0600 - accuracy: 0.9828 - val_loss: 2.2597 - val_accuracy: 0.7452
# Epoch 58/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0705 - accuracy: 0.9810 - val_loss: 2.1249 - val_accuracy: 0.7559
# Epoch 59/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0624 - accuracy: 0.9832 - val_loss: 2.1147 - val_accuracy: 0.7571
# Epoch 60/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0574 - accuracy: 0.9846 - val_loss: 2.0563 - val_accuracy: 0.7571
# Epoch 61/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0572 - accuracy: 0.9843 - val_loss: 2.0896 - val_accuracy: 0.7488
# Epoch 62/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0632 - accuracy: 0.9836 - val_loss: 2.0586 - val_accuracy: 0.7450
# Epoch 63/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0565 - accuracy: 0.9849 - val_loss: 2.1378 - val_accuracy: 0.7519
# Epoch 64/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0623 - accuracy: 0.9830 - val_loss: 2.1086 - val_accuracy: 0.7505
# Epoch 65/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0640 - accuracy: 0.9829 - val_loss: 2.0749 - val_accuracy: 0.7530
# Epoch 66/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0620 - accuracy: 0.9843 - val_loss: 2.0880 - val_accuracy: 0.7549
# Epoch 67/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0691 - accuracy: 0.9821 - val_loss: 2.0325 - val_accuracy: 0.7588
# Epoch 68/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0521 - accuracy: 0.9857 - val_loss: 2.1063 - val_accuracy: 0.7504
# Epoch 69/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0614 - accuracy: 0.9839 - val_loss: 2.1113 - val_accuracy: 0.7527
# Epoch 70/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0642 - accuracy: 0.9834 - val_loss: 2.2307 - val_accuracy: 0.7519
# Epoch 71/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0605 - accuracy: 0.9847 - val_loss: 2.2929 - val_accuracy: 0.7515
# Epoch 72/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0535 - accuracy: 0.9860 - val_loss: 2.3532 - val_accuracy: 0.7476
# Epoch 73/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0620 - accuracy: 0.9841 - val_loss: 2.2696 - val_accuracy: 0.7510
# Epoch 74/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0486 - accuracy: 0.9879 - val_loss: 2.1470 - val_accuracy: 0.7591
# Epoch 75/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0699 - accuracy: 0.9819 - val_loss: 2.0580 - val_accuracy: 0.7535
# Epoch 76/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0615 - accuracy: 0.9840 - val_loss: 1.9801 - val_accuracy: 0.7497
# Epoch 77/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0546 - accuracy: 0.9862 - val_loss: 1.9632 - val_accuracy: 0.7551
# Epoch 78/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0521 - accuracy: 0.9871 - val_loss: 2.1745 - val_accuracy: 0.7513
# Epoch 79/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0564 - accuracy: 0.9856 - val_loss: 2.2461 - val_accuracy: 0.7515
# Epoch 80/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0562 - accuracy: 0.9863 - val_loss: 2.3032 - val_accuracy: 0.7543
# Epoch 81/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0460 - accuracy: 0.9884 - val_loss: 2.4215 - val_accuracy: 0.7520
# Epoch 82/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0638 - accuracy: 0.9840 - val_loss: 2.2843 - val_accuracy: 0.7525
# Epoch 83/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0553 - accuracy: 0.9861 - val_loss: 2.2875 - val_accuracy: 0.7589
# Epoch 84/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0576 - accuracy: 0.9854 - val_loss: 2.1291 - val_accuracy: 0.7531
# Epoch 85/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0480 - accuracy: 0.9884 - val_loss: 2.1293 - val_accuracy: 0.7485
# Epoch 86/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0685 - accuracy: 0.9829 - val_loss: 2.3647 - val_accuracy: 0.7363
# Epoch 87/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0654 - accuracy: 0.9838 - val_loss: 2.0891 - val_accuracy: 0.7460
# Epoch 88/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0468 - accuracy: 0.9879 - val_loss: 2.4496 - val_accuracy: 0.7526
# Epoch 89/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0591 - accuracy: 0.9864 - val_loss: 2.1309 - val_accuracy: 0.7518
# Epoch 90/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0517 - accuracy: 0.9879 - val_loss: 2.3707 - val_accuracy: 0.7485
# Epoch 91/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0535 - accuracy: 0.9861 - val_loss: 2.3638 - val_accuracy: 0.7546
# Epoch 92/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0469 - accuracy: 0.9877 - val_loss: 2.4227 - val_accuracy: 0.7529
# Epoch 93/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0546 - accuracy: 0.9865 - val_loss: 2.3348 - val_accuracy: 0.7446
# Epoch 94/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0528 - accuracy: 0.9869 - val_loss: 2.3849 - val_accuracy: 0.7476
# Epoch 95/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0598 - accuracy: 0.9855 - val_loss: 2.1081 - val_accuracy: 0.7533
# Epoch 96/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0385 - accuracy: 0.9904 - val_loss: 2.4677 - val_accuracy: 0.7527
# Epoch 97/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0597 - accuracy: 0.9867 - val_loss: 2.1710 - val_accuracy: 0.7505
# Epoch 98/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0548 - accuracy: 0.9869 - val_loss: 2.4144 - val_accuracy: 0.7421
# Epoch 99/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0585 - accuracy: 0.9859 - val_loss: 2.1789 - val_accuracy: 0.7574
# Epoch 100/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0410 - accuracy: 0.9899 - val_loss: 2.1440 - val_accuracy: 0.7550

# %% [markdown]
# ## Plotando os erros e acurácias de treinamento e validação em função das épocas de treinamento.

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Época', fontsize=14)
plt.legend(['Train', 'Val'], fontsize=14)
plt.title('Loss', fontsize=14)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Época', fontsize=14)
plt.legend(['Train', 'Val'], fontsize=14)
plt.title('Acurácia', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# ## Aplicando o early-stop.

# %%
# Define VGG model.
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.Conv2D(filters=128,kernel_size=(3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=1024, activation='relu', kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(units=512, activation='relu', kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

# Compile the defined model.
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True)

# Train the VGG model.
history = model.fit(train_images, train_labels, batch_size=64, validation_data=(test_images, test_labels), epochs=100, callbacks=[early_stopping_cb])
# Out:
# Epoch 1/100
# 782/782 [==============================] - 12s 10ms/step - loss: 1.5074 - accuracy: 0.4438 - val_loss: 1.1603 - val_accuracy: 0.5899
# Epoch 2/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.9709 - accuracy: 0.6557 - val_loss: 0.8400 - val_accuracy: 0.7038
# Epoch 3/100
# 782/782 [==============================] - 8s 10ms/step - loss: 0.7592 - accuracy: 0.7326 - val_loss: 0.7454 - val_accuracy: 0.7406
# Epoch 4/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.6123 - accuracy: 0.7848 - val_loss: 0.7551 - val_accuracy: 0.7460
# Epoch 5/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.4978 - accuracy: 0.8248 - val_loss: 0.7213 - val_accuracy: 0.7553
# Epoch 6/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.3990 - accuracy: 0.8591 - val_loss: 0.7465 - val_accuracy: 0.7652
# Epoch 7/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.3100 - accuracy: 0.8894 - val_loss: 0.8248 - val_accuracy: 0.7626
# Epoch 8/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.2396 - accuracy: 0.9165 - val_loss: 0.8609 - val_accuracy: 0.7669
# Epoch 9/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1896 - accuracy: 0.9335 - val_loss: 1.0267 - val_accuracy: 0.7578
# Epoch 10/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1583 - accuracy: 0.9442 - val_loss: 1.0617 - val_accuracy: 0.7633
# Epoch 11/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1389 - accuracy: 0.9513 - val_loss: 1.1489 - val_accuracy: 0.7593
# Epoch 12/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1215 - accuracy: 0.9581 - val_loss: 1.2209 - val_accuracy: 0.7506
# Epoch 13/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1180 - accuracy: 0.9604 - val_loss: 1.3385 - val_accuracy: 0.7532
# Epoch 14/100
# 782/782 [==============================] - 7s 8ms/step - loss: 0.1094 - accuracy: 0.9627 - val_loss: 1.2302 - val_accuracy: 0.7605
# Epoch 15/100
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0959 - accuracy: 0.9678 - val_loss: 1.4015 - val_accuracy: 0.7457

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Época', fontsize=14)
plt.legend(['Train', 'Val'], fontsize=14)
plt.title('Loss', fontsize=14)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Época', fontsize=14)
plt.legend(['Train', 'Val'], fontsize=14)
plt.title('Acurácia', fontsize=14)
plt.grid()
plt.show()
